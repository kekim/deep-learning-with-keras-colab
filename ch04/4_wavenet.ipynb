# %% [markdown]
# https://deepmind.com/blog/wavenet-generative-model-raw-audio/
#
# https://www.youtube.com/watch?v=CqFIVCD1WWo

# %%
# !git clone https://github.com/basveeling/wavenet.git
# Out:
# Cloning into 'wavenet'...
# remote: Enumerating objects: 236, done.
# remote: Total 236 (delta 0), reused 0 (delta 0), pack-reused 236
# Receiving objects: 100% (236/236), 37.44 MiB | 25.22 MiB/s, done.
# Resolving deltas: 100% (123/123), done.

# %%
import os
os.chdir('wavenet')

# %%
# !pip install picklable_itertools sacred
#!pip install sacred
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/75/bc/cda9191f0c92960ede6aa95e364443965246385faf62775cc30749931c2c/picklable-itertools-0.1.1.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/59/25/844c1e9bf5e767b76b9c1df9b7fc8ea323ea8c5065a6bcd9659a33d6db81/sacred-0.7.4-py2.py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/75/d0/7e547b0abfa23234c82100d1bfe670286a3361f4382fc766329f70bc34e8/py-cpuinfo-4.0.0.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/32/d5/2f47f03d3f64c31b0d7070b488274631d7567c36e81a9f744e6638bb0f0d/jsonpickle-0.9.6.tar.gz
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/36/dd/e2/ec30ef7c475e1d9fb966735984ba05f8710c67d7de5358c326
# done
#   Stored in directory: /root/.cache/pip/wheels/bd/e6/74/5f9ff2150a62868acf69169db535d99949f838ac2f8e0b5d4b
# done
#   Stored in directory: /root/.cache/pip/wheels/07/8b/41/8ce98f4737a9ff61b1bf2673f2abfe66a6a43ad6e91d2c9736
# ...

# %%
# !python wavenet.py
# Out:
# Using TensorFlow backend.
# WARNING - wavenet - No observers have been added to this run
# INFO - wavenet - Running command 'main'
# INFO - wavenet - Started
# Configuration (modified, added, typechanged, doc):
#   batch_size = 16
#   data_dir = 'data'
#   data_dir_structure = 'flat'        # Or 'vctk' for a speakerdir structure
#   debug = False
#   desired_sample_rate = 4410
#   dilation_depth = 9
#   early_stopping_patience = 20
#   final_l2 = 0
#   fragment_length = 1152
#   fragment_stride = 128
#   keras_verbose = 1
#   learn_all_outputs = True
#   nb_epoch = 1000
#   nb_filters = 256
#   nb_output_bins = 256
#   nb_stacks = 1
#   predict_initial_input = None
#   predict_seconds = 1
#   predict_use_softmax_as_input = False    # Uses the softmax rather than the argmax as in input for the next step.
#   random_train_batches = False
#   randomize_batch_order = True       # Only effective if not using random train batches
#   res_l2 = 0
#   run_dir = None
#   sample_argmax = False
# ...
